# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
FHS_data = pd.read_excel("C:/Users/erueb/dev/python-projects/STAT400-project-one/Framingham_data.xlsx")

# %%
# Part 1
# Examining gender and coronary heart disease fate to see if a relationship exists

genders = ["Male", "Female"]
# Defining conditions that we will need to look for
male = FHS_data["sex"] == 1
totNumMales = len(FHS_data[male])

female = FHS_data["sex"] == 2
totNumFemales = len(FHS_data[female])

noCHD = FHS_data["chdfate"] == 0
numNoCHD = len(FHS_data[noCHD])

hasCHD = FHS_data["chdfate"] == 1
numHasCHD = len(FHS_data[hasCHD])


print("Number of males: {}".format(totNumMales))
print("Number of females: {}".format(totNumFemales))

# Double check that 0 means NOT disease and 1 means HAS disease
print("Number of people NOT diagnosed with coronary heart disease: {}".format(numNoCHD))
print("Number of people diagnosed with coronary heart disease: {}".format(numHasCHD))
# Out:
# Number of males: 2049
# Number of females: 2650
# Number of people NOT diagnosed with coronary heart disease: 3226
# Number of people diagnosed with coronary heart disease: 1473

# %%
# Histogram for males
numMalesNoCHD = len(FHS_data[male & noCHD])
proportionMaleNoCHD = numMalesNoCHD/totNumMales
numMalesWithCHD = len(FHS_data[male & hasCHD])
proportionMaleHasCHD = numMalesWithCHD/totNumMales
print("Percent of males with CHD is {}".format(100 * proportionMaleHasCHD))
print("Percent of males without CHD is {}".format(100 * proportionMaleNoCHD))
proportionCHDArrM = [proportionMaleNoCHD, proportionMaleHasCHD]
maleCHDGroupsArr = ["No CHD", "Diagnosed with CHD"]

y_pos = np.arange(2)
plt.bar(y_pos, proportionCHDArrM, align='center')
plt.xticks(y_pos, maleCHDGroupsArr)
plt.ylabel('Proportion of all males in study')
plt.title('Relative frequency of male CHD')
axes = plt.gca()
axes.set_ylim([0, 1])
plt.show()
# Out:
# Percent of males with CHD is 40.165934602244995
# Percent of males without CHD is 59.834065397755

# %%
# Histogram for females
numFemalesNoCHD = len(FHS_data[female & noCHD])
proportionFemaleNoCHD = numFemalesNoCHD/totNumFemales
numFemalesWithCHD = len(FHS_data[female & hasCHD])
proportionFemaleHasCHD = numFemalesWithCHD/totNumFemales
print("Percent of females with CHD is {}".format(100 * proportionFemaleHasCHD))
print("Percent of females without CHD is {}".format(100 * proportionFemaleNoCHD))
proportionCHDArrF = [proportionFemaleNoCHD, proportionFemaleHasCHD]
femaleCHDGroupsArr = ["No CHD", "Diagnosed with CHD"]

y_pos = np.arange(2)
plt.bar(y_pos, proportionCHDArrF, align='center')
plt.xticks(y_pos, maleCHDGroupsArr)
plt.ylabel('Proportion of all females in study')
plt.title('Relative frequency of female CHD')
axes = plt.gca()
axes.set_ylim([0, 1])
plt.show()
# Out:
# Percent of females with CHD is 24.528301886792452
# Percent of females without CHD is 75.47169811320755

# %% [markdown]
# ## Part 1 Conclusions
# Based on my analysis of the data, sex appears to have a marked effect on frequency of coronary heart disease (CHD). The proportion of females with CHD was approximately 25%. Meanwhile, the proportion of males with CHD was much higher, at approximately 40%. This large difference in proportion of CHD diagnoses by gender leads me to believe that males are more susceptible to CHD than females.

# %%
# Begin Parts 2 and 3
# Function to generate the histograms for parts 2 and 3
def generateProportionHistogram(title: str, indVar: str, xlabel: str):
    sbp = FHS_data[indVar]
    sbpSortedNoDupes 
    = sbp.sort_values().drop_duplicates().dropna()
    chdPercentages = []
    binnedSortedNoDupes = pd.cut(sbpSortedNoDupes, bins=6, precision = 0)
    bins = pd.Series(binnedSortedNoDupes).drop_duplicates()
    # Calculate proportions
    for interval in bins:
        numHavingCHDForInterval = 0
        totalNumForInterval = 0
        for i in sbpSortedNoDupes:
            if i in interval:
                numOfHasCHDForI = len(sbp.where((sbp == i) & hasCHD).dropna())
                numOfPatientsForSBPLevelI = len(sbp.where(sbp == i).dropna())
                numHavingCHDForInterval += numOfHasCHDForI
                totalNumForInterval += numOfPatientsForSBPLevelI
        chdPercentages.append((numHavingCHDForInterval/totalNumForInterval) * 100) 
    for percent, aBin in zip(chdPercentages, bins):
        print("For interval {}, proportion with CHD is {}".format(aBin, percent))
    labels = []
    for bin in bins:
        str = "{}".format(bin)
        labels.append(str)
    plt.bar(np.arange(0, len(bins)), chdPercentages, tick_label=labels)
    plt.xticks(rotation= 35, horizontalalignment='right')
    plt.xlabel(xlabel)
    axes = plt.gca()
    axes.set_ylim([0, 100])
    plt.ylabel("Percentages")
    plt.title(title)
    plt.show()
# Out:
#   File "<ipython-input-353-236ff586dc44>", line 6
#     = sbp.sort_values().drop_duplicates().dropna()
#     ^
# SyntaxError: invalid syntax

# %%
# Part 2
# Examining the relationship between systemic blood pressure levels and coronary heart disease
title = "Percentage of patients in Systolic Blood Pressure ranges diagnosed with CHD"
generateProportionHistogram(title, "sbp", "Systolic Blood Pressure in mmHg")
# Out:
# For interval (80.0, 112.0], proportion with CHD is 18.203309692671397
# For interval (112.0, 143.0], proportion with CHD is 30.61615001913509
# For interval (143.0, 175.0], proportion with CHD is 40.32258064516129
# For interval (175.0, 207.0], proportion with CHD is 44.1025641025641
# For interval (207.0, 238.0], proportion with CHD is 67.44186046511628
# For interval (238.0, 270.0], proportion with CHD is 57.14285714285714

# %% [markdown]
# # Part 2 Conclusions
# Systolic blood pressure (SBP) levels and CHD diagnoses appear to have a positive relationship. As SBP increases, the proportion of CHD diagnoses generally increases. For example, for patients with SBP in the range of 80 to 112 mmHg, the proportion diagnosed with CHD was approximately 18%. However, for patients in the range of 207 to 238 mmHg, the proportion diagnosed with CHD was approximately 67%. Interestingly, the proportion of CHD diagnoses for the highest range of recorded SBP levels (238 to 270 mmHg) was approximately 57%, which is lower than the proportion of CHD diagnoses for the penultimate range of 207 to 238 mmHg.

# %%
# Part 3
# Examining the relationship between serum cholesterol levels and coronary heart disease
title = "Percentage of patients in Serum Cholesterol Ranges Diagnosed with CHD"
generateProportionHistogram(title, "scl", "Serum Cholesterol in mg/dL")
# Out:
# For interval (115.0, 190.0], proportion with CHD is 20.31425364758698
# For interval (190.0, 266.0], proportion with CHD is 31.896551724137932
# For interval (266.0, 342.0], proportion with CHD is 40.04884004884005
# For interval (342.0, 417.0], proportion with CHD is 51.11111111111111
# For interval (417.0, 492.0], proportion with CHD is 85.71428571428571
# For interval (492.0, 568.0], proportion with CHD is 100.0

# %% [markdown]
# # Part 3 Conclusions
# Serum cholesterol level (SCL) and CHD diagnoses appear to have a positive relationship. As SCL increases, the proportion of CHD diagnoses markedly increases. For example, for patients with SCL in the range of 115 to 190 mg/dL, the proportion diagnosed with CHD was approximately 20%. However, for patients in the range of 417 to 492 mg/dL, the proportion diagnosed with CHD was approximately 86%, and for patients in the range of 492 to 568 mg/dL, 100% were diagnosed with CHD!

# %%
# Part 4
# Examining the relationship between age and coronary heart disease
generateProportionHistogram("Percentage of patients diagnosed with coronary heart disease by age range", "age", "Ages in years")
# Out:
# For interval (30.0, 36.0], proportion with CHD is 20.647773279352226
# For interval (36.0, 43.0], proportion with CHD is 26.053042121684868
# For interval (43.0, 49.0], proportion with CHD is 33.80566801619433
# For interval (49.0, 55.0], proportion with CHD is 36.80555555555556
# For interval (55.0, 62.0], proportion with CHD is 40.21024967148489
# For interval (62.0, 68.0], proportion with CHD is 45.16129032258064

# %%
# Function for getting percentages and differentiating by male or female
def generateAgeCHDProportionHistogramBySex(title: str, indVar: str, xlabel: str, sexInt: int):
    isChosenGender = male if (sexInt == 1) else female
    sbp = FHS_data[indVar]
    sbpSortedNoDupes = sbp.sort_values().drop_duplicates().dropna()
    chdPercentages = []
    binnedSortedNoDupes = pd.cut(sbpSortedNoDupes, bins=6, precision = 0)
    bins = pd.Series(binnedSortedNoDupes).drop_duplicates()
    # Calculate proportions
    for interval in bins:
        numHavingCHDForInterval = 0
        totalNumForInterval = 0
        for i in sbpSortedNoDupes:
            if i in interval:
                numOfHasCHDForI = len(sbp.where((sbp == i) & hasCHD & isChosenGender).dropna())
                numOfPatientsForSBPLevelI = len(sbp.where((sbp == i) & isChosenGender).dropna())
                numHavingCHDForInterval += numOfHasCHDForI
                totalNumForInterval += numOfPatientsForSBPLevelI
        chdPercentages.append((numHavingCHDForInterval/totalNumForInterval) * 100) 
    for percent, aBin in zip(chdPercentages, bins):
        print("For interval {}, proportion with CHD is {}".format(aBin, percent))
    labels = []
    for bin in bins:
        str = "{}".format(bin)
        labels.append(str)
    plt.bar(np.arange(0, len(bins)), chdPercentages, tick_label=labels)
    plt.xticks(rotation= 35, horizontalalignment='right')
    plt.xlabel(xlabel)
    axes = plt.gca()
    axes.set_ylim([0, 100])
    plt.ylabel("Percentages")
    plt.title(title)
    plt.show()

# %%
# Males and coronary heart disease by age
generateAgeCHDProportionHistogramBySex("Percentage of male patients diagnosed with coronary heart disease by age range", "age", "Ages in years", 1)
# Out:
# For interval (30.0, 36.0], proportion with CHD is 28.488372093023255
# For interval (36.0, 43.0], proportion with CHD is 36.66061705989111
# For interval (43.0, 49.0], proportion with CHD is 45.27027027027027
# For interval (49.0, 55.0], proportion with CHD is 45.92391304347826
# For interval (55.0, 62.0], proportion with CHD is 44.27244582043344
# For interval (62.0, 68.0], proportion with CHD is 52.63157894736842

# %%
# Females and coronary heart disease by age
generateAgeCHDProportionHistogramBySex("Percentage of female patients diagnosed with coronary heart disease by age range", "age", "Ages in years", 2)
# Out:
# For interval (30.0, 36.0], proportion with CHD is 13.85390428211587
# For interval (36.0, 43.0], proportion with CHD is 18.057455540355676
# For interval (43.0, 49.0], proportion with CHD is 24.448529411764707
# For interval (49.0, 55.0], proportion with CHD is 30.040322580645164
# For interval (55.0, 62.0], proportion with CHD is 37.21461187214612
# For interval (62.0, 68.0], proportion with CHD is 41.86046511627907

# %%
# Mean age of all patients both with and without CHD
meanAge = np.mean(FHS_data["age"])
medianAge = np.median(FHS_data["age"])
print("Mean age is {} years".format(meanAge))
print("Median age is {} years".format(medianAge))
print("Std Dev in age is {} years".format(np.std(FHS_data["age"])))
# Out:
# Mean age is 46.04107256863163 years
# Median age is 45.0 years
# Std Dev in age is 8.503458392798906 years

# %%
# Mean age of all patients with CHD
agesPatientsWithCHD = FHS_data["age"].where(hasCHD).dropna()
meanAge = np.mean(agesPatientsWithCHD)
medianAge = np.median(agesPatientsWithCHD)
print("Mean age of patients with CHD is {} years".format(meanAge))
print("Median age of patients with CHD is {} years".format(medianAge))
print("Std Dev in age of patients with CHD is {} years".format(np.std(agesPatientsWithCHD)))
# Out:
# Mean age of patients with CHD is 47.883910386965375 years
# Median age of patients with CHD is 48.0 years
# Std Dev in age of patients with CHD is 8.347800693982633 years

# %%
# Mean age of men with CHD
agesOfMalesWithCHD = FHS_data["age"].where(male & hasCHD).dropna()
meanMaleCHDAge = np.mean(agesOfMalesWithCHD)
medianMaleCHDAge = np.median(agesOfMalesWithCHD)
print("Mean age of males with CHD is {} years".format(meanMaleCHDAge))
print("Median age of males with CHD is {} years".format(medianMaleCHDAge))
print("Std Dev in age of males with CHD is {} years".format(np.std(agesOfMalesWithCHD)))
# Out:
# Mean age of males with CHD is 46.933171324422844 years
# Median age of males with CHD is 47.0 years
# Std Dev in age of males with CHD is 8.204948009476087 years

# %%
# Mean age of females with CHD
agesOfFemalesWithCHD = FHS_data["age"].where(female & hasCHD).dropna()
meanFemaleCHDAge= np.mean(agesOfFemalesWithCHD)
medianFemaleCHDAge = np.median(agesOfFemalesWithCHD)
print("Mean age of females with CHD is {} years".format(meanFemaleCHDAge))
print("Median age of females with CHD is {} years".format(medianFemaleCHDAge))
print("Std Dev in age of females with CHD is {} years".format(np.std(agesOfFemalesWithCHD)))
# Out:
# Mean age of females with CHD is 49.08769230769231 years
# Median age of females with CHD is 50.0 years
# Std Dev in age of females with CHD is 8.371747500553138 years

# %% [markdown]
# ## Part 4 Conclusions
# Based on my analysis, age has a definite effect on coronary the occurrence of CHD. As age increases, the likelihood of being diagnosed with CHD also increases. For example, the proportion of CHD diagnoses for people in the age range of 30-36 years old was approximately 21%. However, for the age range of 62 to 68, the proportion of CHD diagnoses was approximately 45%. Proportion of CHD diagnoses continued to increase for each increased age range starting from 30-36 and ending with 62-68.
# Additionally, in a reflection of the findings in Part 1 regarding the greater proportion of males diagnosed with CHD as opposed to females diagnosed with CHD, the proportion of CHD diagnoses for each age range was higher for males than for females. Furthermore, the mean age of males diagnosed with CHD was approximately 47 years while the mean age of females diagnosed with CHD was approximately 49 years. For reference, the mean age of patients diagnosed with CHD was approximately 48 years and the mean age of patients (both with and without CHD) was 46 years. Standard deviations for males with CHD, females with CHD, patients with CHD, and patients in general were all very similar (in the range 8.2 to 8.5 years). Finally, regardless of the slight differences in ages and proportion, both males and females still followed the same general trend of increasing CHD diagnoses as age increased.
